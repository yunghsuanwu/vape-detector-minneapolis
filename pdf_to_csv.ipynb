# %%
import tabula

pdf_file = tabula.read_pdf("haloreport-2024-12-03-2025-02-03-copy.pdf", pages="all")

pdf_file.to_csv("haloreport-2024-12-03-2025-02-03-copy.csv", index=False)
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'
# Error from tabula-java:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[1], line 3
#       1 import tabula
# ----> 3 pdf_file = tabula.read_pdf("haloreport-2024-12-03-2025-02-03-copy.pdf", pages="all")
#       5 pdf_file.to_csv("haloreport-2024-12-03-2025-02-03-copy.csv", index=False)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tabula/io.py:400, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
# ...

# %%
import pdfplumber
import pandas as pd

def extract_table_from_pdf(pdf_path, output_csv):
    all_rows = []
    column_names = None
    page_extracted = 0

    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages):
            table = page.extract_table()
            if not table:
                print(f'Page {page_num+1} has no table.')
                continue  # Skip if no table found on the page
            else:
                page_extracted += 1
                # Assume first row of each page is the header
                page_header = table[0]
                page_rows = table[1:]

                # Save column names only from the first page
                if column_names is None:
                    column_names = page_header

                # Skip headers in subsequent pages
                all_rows.extend(page_rows)

    print(f'Total pages extracted: {page_extracted}')

    # Create DataFrame
    df = pd.DataFrame(all_rows, columns=column_names)

    # Optionally drop rows that are clearly not data
    df.dropna(how='all', inplace=True)

    # Save to CSV
    df.to_csv(output_csv, index=False)

# %%
# Usage
extract_table_from_pdf('haloreport-2024-12-03-2025-02-03-copy.pdf', 'haloreport-2024-12-03-2025-02-03-copy.csv')
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...

# %%
extract_table_from_pdf('haloreport-2024-09-02-2024-12-02-copy.pdf', 'haloreport-2024-09-02-2024-12-02-copy.csv')
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...

# %%
extract_table_from_pdf('haloreport-2025-02-03-2025-03-03-copy.pdf', 'haloreport-2025-02-03-2025-03-03-copy.csv')
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...

# %%
extract_table_from_pdf('haloreport-2025-03-04-2025-04-15-copy.pdf', 'haloreport-2025-03-04-2025-04-15-copy.csv')
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...
